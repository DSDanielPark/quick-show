# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quickshow as qs

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. qs.reduce_dim

# %% [markdown]
# #### Make sample dataframe for `qs.vis_pca`, `qs.vis_tsne2d`, `qs.vis_tsne3d`

# %%
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (5,5)
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.facecolor'] = 'lightgray'

# %%
df = pd.DataFrame([3,2,3,2,3,3,1,1])
df['val'] = [np.array([np.random.randint(0,10000),np.random.randint(0,10000),np.random.randint(0,10000)]) for x in df[0]]
df.columns = ['labels', 'values']
print(df)
# Out:
#    labels              values
# 0       3  [8531, 5038, 2280]
# 1       2  [2195, 4973, 4510]
# 2       3  [2422, 1161, 2535]
# 3       2  [2226, 3520, 2146]
# 4       3  [9146, 6413, 5410]
# 5       3  [6148, 7337, 5904]
# 6       1  [6306, 1833, 3395]
# 7       1  [5165, 2853, 7744]

# %%
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (10,10)

# %% [markdown]
# ## 1.1 qs.vis_tsne2d

# %%
return_df = qs.vis_tsne2d(df, 'values', 'labels', True, 'fig1.png')
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 8 samples in 0.000s...
# [t-SNE] Computed neighbors for 8 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 8 / 8
# [t-SNE] Mean sigma: 2396.873501
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 66.6009293, gradient norm = 0.1579705 (50 iterations in 0.035s)
# [t-SNE] Iteration 100: error = 56.9753914, gradient norm = 0.1416377 (50 iterations in 0.031s)
# [t-SNE] Iteration 150: error = 41.0771599, gradient norm = 0.0802889 (50 iterations in 0.020s)
# [t-SNE] Iteration 200: error = 51.0850983, gradient norm = 0.1555942 (50 iterations in 0.017s)
# [t-SNE] Iteration 250: error = 55.7901306, gradient norm = 0.1521736 (50 iterations in 0.017s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.790131
# [t-SNE] Iteration 300: error = 0.7803538, gradient norm = 0.0006599 (50 iterations in 0.020s)
# [t-SNE] Iteration 350: error = 0.7171988, gradient norm = 0.0002966 (50 iterations in 0.012s)
# [t-SNE] Iteration 400: error = 0.5854939, gradient norm = 0.0005941 (50 iterations in 0.011s)
# [t-SNE] Iteration 450: error = 0.4017453, gradient norm = 0.0007483 (50 iterations in 0.013s)
# [t-SNE] Iteration 500: error = 0.2633035, gradient norm = 0.0005881 (50 iterations in 0.016s)
# [t-SNE] KL divergence after 500 iterations: 0.263303

# %%
return_df
# Out:
#    labels              values   tsne-2d-1   tsne-2d-2
# 0       3  [8531, 5038, 2280]   21.977922  215.010284
# 1       2  [2195, 4973, 4510] -148.579926 -310.617462
# 2       3  [2422, 1161, 2535]   79.796051 -251.458984
# 3       2  [2226, 3520, 2146]  -19.867533 -342.260193
# 4       3  [9146, 6413, 5410] -114.872360  169.818237
# 5       3  [6148, 7337, 5904] -142.311569   44.088799
# 6       1  [6306, 1833, 3395]  126.379776   54.954197
# 7       1  [5165, 2853, 7744] -275.606445  -96.728371

# %% [markdown]
# ## 1.2 qs.vis_tsne3d

# %%
return_df = qs.vis_tsne3d(df, 'values', 'labels', True, 'fig2.png')
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 8 samples in 0.000s...
# [t-SNE] Computed neighbors for 8 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 8 / 8
# [t-SNE] Mean sigma: 2396.873501
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 59.9661026, gradient norm = 0.0003293 (50 iterations in 0.039s)
# [t-SNE] Iteration 100: error = 108.4332047, gradient norm = 0.0005008 (50 iterations in 0.017s)
# [t-SNE] Iteration 150: error = 52.6433525, gradient norm = 0.0001485 (50 iterations in 0.035s)
# [t-SNE] Iteration 200: error = 52.6402740, gradient norm = 0.0001879 (50 iterations in 0.029s)
# [t-SNE] Iteration 250: error = 56.6422844, gradient norm = 0.0004102 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.642284
# [t-SNE] Iteration 300: error = 1.9211824, gradient norm = 0.0000785 (50 iterations in 0.026s)
# [t-SNE] KL divergence after 300 iterations: 1.921182

# %% [markdown]
# ## 1.3 qs.vis_pca

# %%
return_df = qs.vis_pca(df, 'values', 'labels', 2, True, 'fig3.png')
# Out:
# Explained variation per PC(Principal Component): [0.60786397 0.23432247 0.15781357]

# %%
return_df
# Out:
#    labels              values   tsne-2d-1   tsne-2d-2   tsne-3d-1   tsne-3d-2  \
# 0       3  [8531, 5038, 2280]   21.977922  215.010284 -115.453941  -60.444363
# 1       2  [2195, 4973, 4510] -148.579926 -310.617462  171.826828 -365.827454
# 2       3  [2422, 1161, 2535]   79.796051 -251.458984   22.920622  179.100800
# 3       2  [2226, 3520, 2146]  -19.867533 -342.260193   80.474174  240.280609
# 4       3  [9146, 6413, 5410] -114.872360  169.818237   87.908356   -8.631354
# 5       3  [6148, 7337, 5904] -142.311569   44.088799  -25.531797   40.965679
# 6       1  [6306, 1833, 3395]  126.379776   54.954197 -130.218506 -402.185974
# 7       1  [5165, 2853, 7744] -275.606445  -96.728371   35.994877  -10.363493
#
#     tsne-3d-3          PC1          PC2          PC3
# 0    6.725013  2515.081014  2901.755182  -744.044185
# 1  119.096893 -1966.598376 -2050.349458 -1460.445246
# 2  -90.186928 -4326.959726   923.835855   556.089905
# 3   81.978104 -3383.769343   333.032727 -1568.989285
# 4  -75.631699  4637.077158   264.157063    34.389195
# 5  130.641052  2843.640542 -1957.817113 -1355.658239
# 6 -162.970566  -600.567685  1978.877559  1686.368348
# 7   37.088425   282.096415 -2393.491814  2852.289508

# %%
return_df = qs.vis_pca(df, 'values', 'labels', 3, True, 'fig4.png')
# Out:
# Explained variation per PC(Principal Component): [0.60786397 0.23432247 0.15781357]

# %% [markdown]
# # 2. qs.eval_clf_model

# %% [markdown]
# ## 2.1 qs.vis_cm

# %% [markdown]
# #### Make sample dataframe for `qs.vis_cm`

# %%
label_list, num_rows = ['cat', 'dog', 'horse', 'dorphin'], 300
df = pd.DataFrame([label_list[np.random.randint(4)] for _ in range(num_rows)], columns=['real'])
df['predicted'] = [label_list[np.random.randint(4)] for _ in range(num_rows)]  
print(df)
# Out:
#         real predicted
# 0        cat       dog
# 1        cat       cat
# 2        cat       cat
# 3    dorphin       cat
# 4      horse     horse
# ..       ...       ...
# 295      dog   dorphin
# 296    horse     horse
# 297      cat       cat
# 298    horse     horse
# 299    horse     horse
#
# [300 rows x 2 columns]

# %%
df_cr, cm = qs.vis_cm(df, 'real', 'predicted', 'vis_cm.csv', 'vis_cm.png')

# %%
df_cr
# Out:
#                  cat        dog    dorphin      horse  accuracy   macro avg  \
# precision   0.263889   0.171053   0.250000   0.234375      0.23    0.229829
# recall      0.231707   0.194030   0.301370   0.192308      0.23    0.229854
# f1-score    0.246753   0.181818   0.273292   0.211268      0.23    0.228283
# support    82.000000  67.000000  73.000000  78.000000      0.23  300.000000
#
#            weighted avg
# precision      0.232102
# recall         0.230000
# f1-score       0.229483
# support      300.000000

# %%
top_folder_path = r'C:\Users\parkm\Desktop\github\fine-tuned-korean-BERT-news-article-classifier\notebooks\inference_result_df'

# %% [markdown]
# ### Note: `qs.utils.find_all_files`

# %%
qs.find_all_files(top_folder_path, 'metirc.csv')
# Out:
# ['C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp10_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp11_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp1_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp2_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp3_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp4_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp5_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp6_mode2_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp7_mode3_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp8_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp9_mode4_metirc.csv']

# %% [markdown]
# ## 2.2 qs.get_total_cr_df

# %% [markdown]
# #### `Very Important`: To proceed with 2.2 and 2.3 you `must` follow the guide below. <br>
# - `get_total_cr_df`` can be used when saving the `df_cr`` created in `qs.vis_cm`` as a csv file. In this case, the csv file name must consist of exp1, exp2 ... expn, a suffix mixed with exp and integers, and the integers must be continuous.
# - Refer to the return list of qs.find_all_files printed in the block immediately above.

# %%
df = qs.get_total_cr_df(top_folder_path, 'metirc.csv', 'df_total_metric.csv')
df
# Out:
#        metric    culture     economy  entertain  international         it  \
# 0   precision   0.750000    0.789916   0.882353       0.896825   0.739130
# 1      recall   0.800000    0.803419   0.914634       0.911290   0.944444
# 2    f1-score   0.774194    0.796610   0.898204       0.904000   0.829268
# 3     support  15.000000  117.000000  82.000000     124.000000  18.000000
# 4   precision   0.846154    0.838983   0.866667       0.902655   0.523810
# 5      recall   0.733333    0.846154   0.951220       0.822581   0.611111
# 6    f1-score   0.785714    0.842553   0.906977       0.860759   0.564103
# 7     support  15.000000  117.000000  82.000000     124.000000  18.000000
# 8   precision   0.833333    0.867347   0.877778       0.868852   0.666667
# 9      recall   0.666667    0.726496   0.963415       0.854839   0.666667
# 10   f1-score   0.740741    0.790698   0.918605       0.861789   0.666667
# 11    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 12  precision   0.916667    0.825688   0.791667       0.869159   0.705882
# 13     recall   0.733333    0.769231   0.926829       0.750000   0.666667
# 14   f1-score   0.814815    0.796460   0.853933       0.805195   0.685714
# 15    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 16  precision   0.833333    0.693878   0.868132       0.878049   0.722222
# 17     recall   0.666667    0.871795   0.963415       0.870968   0.722222
# 18   f1-score   0.740741    0.772727   0.913295       0.874494   0.722222
# 19    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 20  precision   0.857143    0.805085   0.916667       0.888000   0.705882
# 21     recall   0.800000    0.811966   0.939024       0.895161   0.666667
# 22   f1-score   0.827586    0.808511   0.927711       0.891566   0.685714
# 23    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 24  precision   0.777778    0.861111   0.894118       0.882812   0.736842
# 25     recall   0.466667    0.794872   0.926829       0.911290   0.777778
# 26   f1-score   0.583333    0.826667   0.910180       0.896825   0.756757
# 27    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 28  precision   0.769231    0.847619   0.885057       0.885246   0.714286
# 29     recall   0.666667    0.760684   0.939024       0.870968   0.833333
# 30   f1-score   0.714286    0.801802   0.911243       0.878049   0.769231
# 31    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 32  precision   0.764706    0.796748   0.903614       0.888889   0.736842
# 33     recall   0.866667    0.837607   0.914634       0.903226   0.777778
# 34   f1-score   0.812500    0.816667   0.909091       0.896000   0.756757
# 35    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 36  precision   0.785714    0.914894   0.904762       0.881890   0.700000
# 37     recall   0.733333    0.735043   0.926829       0.903226   0.777778
# 38   f1-score   0.758621    0.815166   0.915663       0.892430   0.736842
# 39    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 40  precision   0.900000    0.729927   0.907895       0.912281   0.560000
# 41     recall   0.600000    0.854701   0.841463       0.838710   0.777778
# 42   f1-score   0.720000    0.787402   0.873418       0.873950   0.651163
# 43    support  15.000000  117.000000  82.000000     124.000000  18.000000
#
#       politics     society       sport  accuracy   macro avg  weighted avg  \
# 0     0.961783    0.874564    0.906977  0.881104    0.850194      0.883224
# 1     0.867816    0.850847    1.000000  0.881104    0.886556      0.881104
# 2     0.912387    0.862543    0.951220  0.881104    0.866053      0.881093
# 3   174.000000  295.000000  117.000000  0.881104  942.000000    942.000000
# 4     0.942446    0.827044    0.900000  0.861996    0.830970      0.866817
# 5     0.752874    0.891525    1.000000  0.861996    0.826100      0.861996
# 6     0.837061    0.858075    0.947368  0.861996    0.825326      0.861197
# 7   174.000000  295.000000  117.000000  0.861996  942.000000    942.000000
# 8     0.927152    0.820669    0.942623  0.867304    0.850553      0.869855
# 9     0.804598    0.915254    0.982906  0.867304    0.822605      0.867304
# 10    0.861538    0.865385    0.962343  0.867304    0.833471      0.865818
# 11  174.000000  295.000000  117.000000  0.867304  942.000000    942.000000
# 12    0.868750    0.790909    0.963964  0.837580    0.841586      0.841845
# 13    0.798851    0.884746    0.914530  0.837580    0.805523      0.837580
# 14    0.832335    0.835200    0.938596  0.837580    0.820281      0.837201
# 15  174.000000  295.000000  117.000000  0.837580  942.000000    942.000000
# 16    0.965278    0.874101    0.906977  0.860934    0.842746      0.869090
# 17    0.798851    0.823729    1.000000  0.860934    0.839706      0.860934
# 18    0.874214    0.848168    0.951220  0.860934    0.837135      0.861426
# 19  174.000000  295.000000  117.000000  0.860934  942.000000    942.000000
# 20    0.904459    0.854785    0.935484  0.874735    0.858438      0.874762
# 21    0.816092    0.877966    0.991453  0.874735    0.849791      0.874735
# 22    0.858006    0.866221    0.962656  0.874735    0.853496      0.874138
# 23  174.000000  295.000000  117.000000  0.874735  942.000000    942.000000
# 24    0.924051    0.866883    0.921260  0.884289    0.858107      0.884043
# 25    0.839080    0.905085    1.000000  0.884289    0.827700      0.884289
# 26    0.879518    0.885572    0.959016  0.884289    0.837234      0.882609
# 27  174.000000  295.000000  117.000000  0.884289  942.000000    942.000000
# 28    0.892216    0.861842    0.951220  0.877919    0.850840      0.877594
# 29    0.856322    0.888136    1.000000  0.877919    0.851892      0.877919
# 30    0.873900    0.874791    0.975000  0.877919    0.849788      0.877036
# 31  174.000000  295.000000  117.000000  0.877919  942.000000    942.000000
# 32    0.919255    0.888889    0.936000  0.884289    0.854368      0.885304
# 33    0.850575    0.867797    1.000000  0.884289    0.877285      0.884289
# 34    0.883582    0.878216    0.966942  0.884289    0.864969      0.884244
# 35  174.000000  295.000000  117.000000  0.884289  942.000000    942.000000
# 36    0.930818    0.843077    0.974790  0.888535    0.866993      0.891394
# 37    0.850575    0.928814    0.991453  0.888535    0.855881      0.888535
# 38    0.888889    0.883871    0.983051  0.888535    0.859317      0.887673
# 39  174.000000  295.000000  117.000000  0.888535  942.000000    942.000000
# 40    0.898810    0.897810    0.847826  0.859873    0.831819      0.867297
# 41    0.867816    0.833898    1.000000  0.859873    0.826796      0.859873
# 42    0.883041    0.864675    0.917647  0.859873    0.821412      0.860647
# 43  174.000000  295.000000  117.000000  0.859873  942.000000    942.000000
#
#     exp
# 0     9
# 1     9
# 2     9
# 3     9
# 4     8
# 5     8
# 6     8
# 7     8
# 8     7
# 9     7
# 10    7
# 11    7
# 12    6
# 13    6
# 14    6
# 15    6
# 16    5
# 17    5
# 18    5
# 19    5
# 20    4
# 21    4
# 22    4
# 23    4
# 24    3
# 25    3
# 26    3
# 27    3
# 28    2
# 29    2
# 30    2
# 31    2
# 32    1
# 33    1
# 34    1
# 35    1
# 36   11
# 37   11
# 38   11
# 39   11
# 40   10
# 41   10
# 42   10
# 43   10

# %%
# Print qs.utils.rcparam to see useful plt rcparam options.
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.grid'] = False 
plt.rcParams['axes.facecolor'] = 'white'

# %% [markdown]
# ## 2.3 qs.vis_multi_plot
# - Receive the return dataframe of `qs.get_total_cr_df` in 2.2 above as input and visualize the performance of the classification model for each class in each experiment as follows.

# %%
qs.vis_multi_plot(df, 'precision', ['metric', 'exp', 'weighted avg', 'macro avg'], None)
# Out:
#        metric   culture   economy  entertain  international        it  \
# 36  precision  0.785714  0.914894   0.904762       0.881890  0.700000
# 40  precision  0.900000  0.729927   0.907895       0.912281  0.560000
# 0   precision  0.750000  0.789916   0.882353       0.896825  0.739130
# 4   precision  0.846154  0.838983   0.866667       0.902655  0.523810
# 8   precision  0.833333  0.867347   0.877778       0.868852  0.666667
# 12  precision  0.916667  0.825688   0.791667       0.869159  0.705882
# 16  precision  0.833333  0.693878   0.868132       0.878049  0.722222
# 20  precision  0.857143  0.805085   0.916667       0.888000  0.705882
# 24  precision  0.777778  0.861111   0.894118       0.882812  0.736842
# 28  precision  0.769231  0.847619   0.885057       0.885246  0.714286
# 32  precision  0.764706  0.796748   0.903614       0.888889  0.736842
#
#     politics   society     sport  accuracy  macro avg  weighted avg  exp
# 36  0.930818  0.843077  0.974790  0.888535   0.866993      0.891394   11
# 40  0.898810  0.897810  0.847826  0.859873   0.831819      0.867297   10
# 0   0.961783  0.874564  0.906977  0.881104   0.850194      0.883224    9
# 4   0.942446  0.827044  0.900000  0.861996   0.830970      0.866817    8
# 8   0.927152  0.820669  0.942623  0.867304   0.850553      0.869855    7
# 12  0.868750  0.790909  0.963964  0.837580   0.841586      0.841845    6
# 16  0.965278  0.874101  0.906977  0.860934   0.842746      0.869090    5
# 20  0.904459  0.854785  0.935484  0.874735   0.858438      0.874762    4
# 24  0.924051  0.866883  0.921260  0.884289   0.858107      0.884043    3
# 28  0.892216  0.861842  0.951220  0.877919   0.850840      0.877594    2
# 32  0.919255  0.888889  0.936000  0.884289   0.854368      0.885304    1

# %% [markdown]
# # 3. quickshow.cluster

# %% [markdown]
# #### Make sample dataframe for `qs.vis_cluster_plot`

# %%
num_rows = 300
df = pd.DataFrame([np.random.randint(8) for _ in range(num_rows)], columns=['real_label'])
df['cluster'] = [np.random.randint(13) for _ in range(num_rows)]  
print(df)
# Out:
#      real_label  cluster
# 0             2        4
# 1             2       11
# 2             2        2
# 3             7       10
# 4             0        3
# ..          ...      ...
# 295           1       11
# 296           1        2
# 297           2       11
# 298           3        3
# 299           5       10
#
# [300 rows x 2 columns]

# %%
# Print qs.utils.rcparam to see useful plt rcparam options.
plt.rcParams["figure.figsize"] = (30,10)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = False 
plt.rcParams['axes.facecolor'] = 'lightgray'

# %%
df_pivot = qs.vis_cluster_plot(df, 'cluster', 'real_label', None)

# %%
df_pivot
# Out:
# real_label          0  1  2  3  4  5  6  7
# cluster real_label
# 0       0           3  0  0  0  0  0  0  0
#         1           0  3  0  0  0  0  0  0
#         2           0  0  2  0  0  0  0  0
#         3           0  0  0  4  0  0  0  0
#         4           0  0  0  0  2  0  0  0
# ...                .. .. .. .. .. .. .. ..
# 12      2           0  0  2  0  0  0  0  0
#         3           0  0  0  5  0  0  0  0
#         4           0  0  0  0  6  0  0  0
#         5           0  0  0  0  0  6  0  0
#         7           0  0  0  0  0  0  0  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Further Reading
# [1] Seaborn color palettes https://seaborn.pydata.org/tutorial/color_palettes.html <Br>
# [2] set_matplotlib rcparam https://matplotlib.org/stable/tutorials/introductory/customizing.html <br>
