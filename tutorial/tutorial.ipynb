# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quickshow as qs

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# You can easily find example code in qs.utils.rcparam docstring
qs.utils.rcparam?
# Out:
# Signature: qs.utils.rcparam(**args)
# Docstring:
# Some rcparam example
# plt.style.use('tableau-colorblind10')
# plt.rcParams["figure.figsize"] = (20,10)
# plt.rcParams['lines.linewidth'] = 4
# plt.rcParams['axes.grid'] = False
# plt.rcParams['axes.facecolor'] = 'white'
# File:      c:\users\parkm\appdata\roaming\python\python39\site-packages\quickshow\utils.py
# Type:      function

# %%
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (5,5)
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.facecolor'] = 'lightgray'

# %% [markdown]
# # 1. qs.reduce_dim

# %% [markdown]
# #### Make sample dataframe for `qs.vis_pca`, `qs.vis_tsne2d`, `qs.vis_tsne3d`

# %%
df = pd.DataFrame([3,2,3,2,3,3,1,1])
df['val'] = [np.array([np.random.randint(0,10000),np.random.randint(0,10000),np.random.randint(0,10000)]) for x in df[0]]
df.columns = ['labels', 'values']
print(df)
# Out:
#    labels              values
# 0       3  [6204, 5378, 9268]
# 1       2  [5552, 3958, 7309]
# 2       3   [7951, 845, 7469]
# 3       2   [999, 2199, 5478]
# 4       3  [6674, 1740, 4983]
# 5       3   [825, 7867, 8260]
# 6       1  [5651, 2877, 6973]
# 7       1  [5977, 1780, 6796]

# %%
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (10,10)

# %% [markdown]
# ## 1.1 qs.vis_tsne2d

# %%
return_df = qs.vis_tsne2d(df, 'values', 'labels', True, 'fig1.png')

# %%
return_df
# Out:
#    labels              values  tsne-2d-1  tsne-2d-2
# 0       3  [6204, 5378, 9268]  39.476223 -94.621094
# 1       2  [5552, 3958, 7309] -25.611458 -83.681831
# 2       3   [7951, 845, 7469] -57.640522 -25.972435
# 3       2   [999, 2199, 5478]  18.290833 -21.572802
# 4       3  [6674, 1740, 4983] -32.490326  35.049122
# 5       3   [825, 7867, 8260]  84.793236  15.335471
# 6       1  [5651, 2877, 6973]  88.612213 -50.554482
# 7       1  [5977, 1780, 6796]  30.898468  53.434536

# %% [markdown]
# ## 1.2 qs.vis_tsne3d

# %%
return_df = qs.vis_tsne3d(df, 'values', 'labels', True, 'fig2.png')

# %% [markdown]
# ## 1.3 qs.vis_pca

# %%
return_df = qs.vis_pca(df, 'values', 'labels', 2, True, 'fig3.png')
# Out:
# Explained variation per PC(Principal Component): [0.68620014 0.2845927  0.02920716]

# %%
return_df.head()
# Out:
#    labels              values  tsne-2d-1  tsne-2d-2   tsne-3d-1   tsne-3d-2  \
# 0       3  [6204, 5378, 9268]  39.476223 -94.621094 -219.616547   30.237862
# 1       2  [5552, 3958, 7309] -25.611458 -83.681831 -270.687988  385.188538
# 2       3   [7951, 845, 7469] -57.640522 -25.972435  213.434860  151.927780
# 3       2   [999, 2199, 5478]  18.290833 -21.572802  248.048920 -127.656570
# 4       3  [6674, 1740, 4983] -32.490326  35.049122  -30.142534  266.635620
#
#     tsne-3d-3          PC1          PC2          PC3
# 0  -94.232559   750.999552 -3146.755721  -266.278277
# 1   76.408493    16.805889  -823.564215   319.320469
# 2   54.416073 -3766.586745  -656.749803  -743.545057
# 3  113.791489  1991.065379  3919.790357  -563.480683
# 4  -37.876637 -2613.815513  1098.458331  1306.409307

# %%
return_df = qs.vis_pca(df, 'values', 'labels', 3, True, 'fig4.png')
# Out:
# Explained variation per PC(Principal Component): [0.68620014 0.2845927  0.02920716]

# %% [markdown]
# # 2. qs.eval_clf_model

# %% [markdown]
# ## 2.1 qs.vis_cm

# %% [markdown]
# #### Make sample dataframe for `qs.vis_cm`

# %%
label_list, num_rows = ['cat', 'dog', 'horse', 'dorphin'], 300
df = pd.DataFrame([label_list[np.random.randint(4)] for _ in range(num_rows)], columns=['real'])
df['predicted'] = [label_list[np.random.randint(4)] for _ in range(num_rows)]  
print(df)
# Out:
#         real predicted
# 0    dorphin     horse
# 1        cat       cat
# 2      horse     horse
# 3        dog     horse
# 4      horse       cat
# ..       ...       ...
# 295  dorphin       cat
# 296      dog     horse
# 297      cat       dog
# 298  dorphin     horse
# 299  dorphin     horse
#
# [300 rows x 2 columns]

# %%
df_cr, cm = qs.vis_cm(df, 'real', 'predicted', 'vis_cm.csv', 'vis_cm.png')

# %%
df_cr
# Out:
#                  cat        dog    dorphin      horse  accuracy   macro avg  \
# precision   0.289855   0.209677   0.229730   0.273684  0.253333    0.250737
# recall      0.266667   0.188406   0.217949   0.333333  0.253333    0.251589
# f1-score    0.277778   0.198473   0.223684   0.300578  0.253333    0.250128
# support    75.000000  69.000000  78.000000  78.000000  0.253333  300.000000
#
#            weighted avg
# precision      0.251577
# recall         0.253333
# f1-score       0.251401
# support      300.000000

# %%
cm
# Out:
# array([[20, 13, 21, 21],
#        [13, 13, 20, 23],
#        [17, 19, 17, 25],
#        [19, 17, 16, 26]], dtype=int64)

# %%
top_folder_path = r'C:\Users\parkm\Desktop\github\fine-tuned-korean-BERT-news-article-classifier\notebooks\inference_result_df'

# %% [markdown]
# ### Note: `qs.utils.find_all_files`

# %%
qs.find_all_files(top_folder_path, 'metirc.csv')
# Out:
# ['C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp10_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp11_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp1_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp2_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp3_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp4_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp5_mode1_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp6_mode2_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp7_mode3_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp8_mode4_metirc.csv',
#  'C:\\Users\\parkm\\Desktop\\github\\fine-tuned-korean-BERT-news-article-classifier\\notebooks\\inference_result_df\\exp9_mode4_metirc.csv']

# %% [markdown]
# ## 2.2 qs.get_total_cr_df

# %% [markdown]
# #### `Very Important`: To proceed with 2.2 and 2.3 you `must` follow the guide below. <br>
# - `get_total_cr_df`` can be used when saving the `df_cr`` created in `qs.vis_cm`` as a csv file. In this case, the csv file name must consist of exp1, exp2 ... expn, a suffix mixed with exp and integers, and the integers must be continuous.
# - Refer to the return list of qs.find_all_files printed in the block immediately above.

# %%
total_cr_Df = qs.get_total_cr_df(top_folder_path, 'metirc.csv', 'df_total_metric.csv')
total_cr_Df.head()
# Out:
#       metric    culture     economy  entertain  international         it  \
# 0  precision   0.750000    0.789916   0.882353       0.896825   0.739130
# 1     recall   0.800000    0.803419   0.914634       0.911290   0.944444
# 2   f1-score   0.774194    0.796610   0.898204       0.904000   0.829268
# 3    support  15.000000  117.000000  82.000000     124.000000  18.000000
# 4  precision   0.846154    0.838983   0.866667       0.902655   0.523810
#
#      politics     society       sport  accuracy   macro avg  weighted avg  exp
# 0    0.961783    0.874564    0.906977  0.881104    0.850194      0.883224    9
# 1    0.867816    0.850847    1.000000  0.881104    0.886556      0.881104    9
# 2    0.912387    0.862543    0.951220  0.881104    0.866053      0.881093    9
# 3  174.000000  295.000000  117.000000  0.881104  942.000000    942.000000    9
# 4    0.942446    0.827044    0.900000  0.861996    0.830970      0.866817    8

# %%
# Print qs.utils.rcparam to see useful plt rcparam options.
plt.style.use('tableau-colorblind10')
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.grid'] = False 
plt.rcParams['axes.facecolor'] = 'white'

# %% [markdown]
# ## 2.3 qs.vis_multi_plot
# - Receive the return dataframe of `qs.get_total_cr_df` in 2.2 above as input and visualize the performance of the classification model for each class in each experiment as follows.

# %%
return_df = qs.vis_multi_plot(df, 'precision', ['metric', 'exp', 'weighted avg', 'macro avg'], None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'metric'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\parkm\Desktop\github\quickshow\quickshow\tutorial.ipynb Cell 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/parkm/Desktop/github/quickshow/quickshow/tutorial.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> return_df = qs.vis_multi_plot(df, 'precision', ['metric', 'exp', 'weighted avg', 'macro avg'], None)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\quickshow\eval_clf_model.py:93, in vis_multi_plot(df, which_metirc, except_col, save_path)
#      92 def vis_multi_plot(df: pd.DataFrame, which_metirc: str, except_col: str, save_path: str) -> pd.DataFrame:
# ---> 93     df = df[df['metric'] == which_metirc]
#      94     df = df.sort_values(by='exp' ,ascending=False)
#      95     for i, col in enumerate(df.columns):
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'metric'

# %%
return_df.head()

# %% [markdown]
# # 3. quickshow.cluster

# %% [markdown]
# #### Make sample dataframe for `qs.vis_cluster_plot`

# %%
num_rows = 300
df = pd.DataFrame([np.random.randint(8) for _ in range(num_rows)], columns=['real_label'])
df['cluster'] = [np.random.randint(13) for _ in range(num_rows)]  
print(df)

# %%
# Print qs.utils.rcparam to see useful plt rcparam options.
plt.rcParams["figure.figsize"] = (30,10)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = False 
plt.rcParams['axes.facecolor'] = 'lightgray'

# %% [markdown]
# ## 3.1 qs.vis_cluster_plot

# %%
df_pivot = qs.vis_cluster_plot(df, 'cluster', 'real_label', None)

# %%
df_pivot

# %% [markdown]
# # Further Reading
# [1] Seaborn color palettes https://seaborn.pydata.org/tutorial/color_palettes.html <Br>
# [2] set_matplotlib rcparam https://matplotlib.org/stable/tutorials/introductory/customizing.html <br>
